# %%
import pstats
import h5py
import cProfile
import os
import numpy as np

# %% [markdown]
# ## testing

# %%
def myfunc1():
    chunk_path = get_chunk_path(99)
    with h5py.File(chunk_path) as f:
        m = np.array(f['PartType0/Masses'])
        eta_e = np.array(f['PartType0/ElectronAbundance'])
        X_H = np.array(f['PartType0/GFM_Metals'][:,0])

def myfunc2():
    chunk_path = get_chunk_path(99)
    with h5py.File(chunk_path) as f:
        F = f['PartType0']
        m = np.array(F['Masses'])
        eta_e = np.array(F['ElectronAbundance'])
        X_H = np.array(F['GFM_Metals'][:,0])

# %%
cProfile.run('myfunc1()', sort='tottime')
# Out:
#          305 function calls (302 primitive calls) in 4.175 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    3.355    1.118    3.640    1.213 {built-in method numpy.array}
#         1    0.459    0.459    0.459    0.459 {method 'read' of 'h5py._selector.Reader' objects}
#         2    0.283    0.142    0.283    0.142 dataset.py:1001(read_direct)
#         3    0.031    0.010    0.032    0.011 group.py:348(__getitem__)
#         1    0.031    0.031    0.031    0.031 files.py:211(make_fid)
#         1    0.006    0.006    0.006    0.006 files.py:576(close)
#         1    0.006    0.006    4.175    4.175 <string>:1(<module>)
#         1    0.001    0.001    4.169    4.169 3247447286.py:1(myfunc1)
#         1    0.000    0.000    0.000    0.000 files.py:115(make_fapl)
#         3    0.000    0.000    0.000    0.000 dataset.py:636(__init__)
# ...

# %%
cProfile.run('myfunc2()', sort='tottime')
# Out:
#          328 function calls (325 primitive calls) in 5.055 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    4.035    1.345    4.292    1.431 {built-in method numpy.array}
#         1    0.708    0.708    0.708    0.708 {method 'read' of 'h5py._selector.Reader' objects}
#         2    0.257    0.128    0.257    0.128 dataset.py:1001(read_direct)
#         4    0.033    0.008    0.034    0.008 group.py:348(__getitem__)
#         1    0.009    0.009    0.009    0.009 files.py:211(make_fid)
#         1    0.006    0.006    5.049    5.049 3247447286.py:8(myfunc2)
#         1    0.005    0.005    5.055    5.055 <string>:1(<module>)
#         1    0.001    0.001    0.001    0.001 files.py:576(close)
#         3    0.000    0.000    0.000    0.000 dataset.py:636(__init__)
#         1    0.000    0.000    0.001    0.001 files.py:601(__exit__)
# ...

# %% [markdown]
# ## L35n270TNG

# %%
stats.sort_stats('tottime')  # You can choose different sort options
stats.print_stats()
# Out:
# Fri Jan 12 14:54:56 2024    profile_stats
#
#          79881 function calls (78050 primitive calls) in 11.347 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        33    2.983    0.090    2.988    0.091 /opt/conda/lib/python3.11/site-packages/h5py/_hl/dataset.py:1001(read_direct)
#        11    2.637    0.240    2.637    0.240 {method 'read' of 'h5py._selector.Reader' objects}
#         1    1.744    1.744   11.346   11.346 /home/tnguser/frb_project/create_n_e_map.py:26(sort_chunks_to_bins)
#        55    0.994    0.018    1.008    0.018 /opt/conda/lib/python3.11/site-packages/h5py/_hl/group.py:348(__getitem__)
#        11    0.599    0.054    0.599    0.054 /opt/conda/lib/python3.11/site-packages/h5py/_hl/files.py:576(close)
#        12    0.405    0.034    0.405    0.034 {method 'factorize' of 'pandas._libs.hashtable.Float64HashTable' objects}
# ...

# %%
stats = pstats.Stats('n_e_maps/L35n270TNG/runtime_stats')

# %%
stats.sort_stats('tottime')  # You can choose different sort options
stats.print_stats()
# Out:
# Fri Jan 12 19:22:44 2024    n_e_maps/L35n270TNG/runtime_stats
#
#          36656 function calls (36183 primitive calls) in 11.199 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        33    2.996    0.091    3.001    0.091 /opt/conda/lib/python3.11/site-packages/h5py/_hl/dataset.py:1001(read_direct)
#        11    2.539    0.231    2.539    0.231 {method 'read' of 'h5py._selector.Reader' objects}
#         1    1.762    1.762   11.197   11.197 /home/tnguser/frb_project/create_n_e_map.py:26(sort_chunks_to_bins)
#        44    0.996    0.023    1.009    0.023 /opt/conda/lib/python3.11/site-packages/h5py/_hl/group.py:348(__getitem__)
#        11    0.657    0.060    0.657    0.060 /opt/conda/lib/python3.11/site-packages/h5py/_hl/files.py:576(close)
#        11    0.582    0.053    0.582    0.053 {method 'factorize' of 'pandas._libs.hashtable.Float64HashTable' objects}
# ...

# %% [markdown]
# ## L35n540TNG

# %%
stats = pstats.Stats('n_e_maps/L35n540TNG/runtime_stats')

# %%
stats.sort_stats('tottime')  # You can choose different sort options
stats.print_stats()
# Out:
# Fri Jan 12 15:03:54 2024    n_e_maps/L35n540TNG/runtime_stats
#
#          79133 function calls (77327 primitive calls) in 145.243 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       245   50.621    0.207   63.299    0.258 {built-in method numpy.array}
#         1   18.273   18.273  145.243  145.243 /home/tnguser/frb_project/create_n_e_map.py:26(sort_chunks_to_bins)
#        66   17.851    0.270   17.851    0.270 {method 'copy' of 'numpy.ndarray' objects}
#        33   17.323    0.525   17.323    0.525 {function Quantity.__array_ufunc__ at 0x7fc4e92a6160}
#        33   12.666    0.384   12.670    0.384 /opt/conda/lib/python3.11/site-packages/h5py/_hl/dataset.py:1001(read_direct)
#        11    7.136    0.649    7.136    0.649 /opt/conda/lib/python3.11/site-packages/astropy/units/core.py:1046(convert)
#        11    5.154    0.469    5.154    0.469 {method 'read' of 'h5py._selector.Reader' objects}
# ...

# %% [markdown]
# ## L205n2500TNG

# %%
stats = pstats.Stats('n_e_maps/L205n2500TNG/runtime_stats')

# %%
stats.sort_stats('tottime')  # You can choose different sort options
stats.print_stats()
# Out:
# Fri Jan 12 21:51:51 2024    n_e_maps/L205n2500TNG/runtime_stats
#
#          1994646 function calls (1968846 primitive calls) in 8056.897 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1 1914.591 1914.591 8056.891 8056.891 /home/tnguser/frb_project/create_n_e_map.py:29(sort_chunks_to_bins)
#      1800 1693.292    0.941 1693.292    0.941 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#      1800 1005.275    0.558 1005.518    0.559 /opt/conda/lib/python3.11/site-packages/h5py/_hl/dataset.py:1001(read_direct)
#       600  732.217    1.220  732.217    1.220 {method 'read' of 'h5py._selector.Reader' objects}
#       600  525.094    0.875  525.094    0.875 {method 'factorize' of 'pandas._libs.hashtable.Float64HashTable' objects}
#      7800  390.315    0.050 1396.292    0.179 {built-in method numpy.array}
# ...

# %%
s = """2	0.0769	12
3	0.0833	11
4	0.0909	10
6	0.1	9
8	0.1111	8
11	0.125	7
13	0.1429	6
17	0.1667	5
21	0.2	4
25	0.25	3
33	0.3333	2
40	0.4	1.5
50	0.5	1
59	0.5882	0.7
67	0.6667	0.5
72	0.7143	0.4
78	0.7692	0.3
84	0.8333	0.2
91	0.9091	0.1
99"""

# %%
[int(a.split('\t')[0]) for a in s.split('\n')]
# Out:
# [2, 3, 4, 6, 8, 11, 13, 17, 21, 25, 33, 40, 50, 59, 67, 72, 78, 84, 91, 99]
